# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: annotated-types==0.7.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: anyio==4.4.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (4.4.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: asttokens==2.4.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: async-lru==2.0.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: attrs==23.2.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (23.2.0)
# Requirement already satisfied: Babel==2.15.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (2.15.0)
# Requirement already satisfied: beautifulsoup4==4.12.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (4.12.3)
# Requirement already satisfied: bleach==6.1.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (6.1.0)
# Requirement already satisfied: blinker==1.8.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.8.2)
# Requirement already satisfied: certifi==2024.6.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (2024.6.2)
# Requirement already satisfied: cffi==1.16.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (1.16.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (8.1.7)
# Requirement already satisfied: comm==0.2.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (0.2.2)
# Requirement already satisfied: debugpy==1.8.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (1.8.1)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (0.7.1)
# Requirement already satisfied: dnspython==2.6.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (2.6.1)
# Requirement already satisfied: email_validator==2.1.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (2.1.1)
# Requirement already satisfied: exceptiongroup==1.2.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (1.2.1)
# Requirement already satisfied: executing==2.0.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (2.0.1)
# Requirement already satisfied: fastapi==0.111.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (0.111.0)
# Requirement already satisfied: fastapi-cli==0.0.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (0.0.4)
# Requirement already satisfied: fastjsonschema==2.19.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (2.19.1)
# Requirement already satisfied: Flask==3.0.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (3.0.3)
# Requirement already satisfied: fqdn==1.5.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (1.5.1)
# Requirement already satisfied: h11==0.14.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.5 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (1.0.5)
# Requirement already satisfied: httptools==0.6.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (0.6.1)
# Requirement already satisfied: httpx==0.27.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (0.27.0)
# Requirement already satisfied: idna==3.7 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (3.7)
# Requirement already satisfied: ipykernel==6.29.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (6.29.4)
# Requirement already satisfied: ipython==8.25.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (8.25.0)
# Requirement already satisfied: ipywidgets==8.1.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (8.1.3)
# Requirement already satisfied: isoduration==20.11.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (20.11.0)
# Requirement already satisfied: itsdangerous==2.2.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (2.2.0)
# Requirement already satisfied: jedi==0.19.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 40)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (3.1.4)
# Requirement already satisfied: joblib==1.4.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (1.4.2)
# Requirement already satisfied: json5==0.9.25 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (0.9.25)
# Requirement already satisfied: jsonpointer==3.0.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 44)) (3.0.0)
# Requirement already satisfied: jsonschema==4.22.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (4.22.0)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 46)) (2023.12.1)
# Requirement already satisfied: jupyter==1.0.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 47)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.6.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.10.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 49)) (0.10.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 50)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 51)) (8.6.2)
# Requirement already satisfied: jupyter_core==5.7.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 52)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.14.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 53)) (2.14.1)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 54)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.2.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 55)) (4.2.2)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 56)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 57)) (2.27.2)
# Requirement already satisfied: jupyterlab_widgets==3.0.11 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 58)) (3.0.11)
# Requirement already satisfied: markdown-it-py==3.0.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 59)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 60)) (2.1.5)
# Requirement already satisfied: matplotlib-inline==0.1.7 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 61)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 62)) (0.1.2)
# Requirement already satisfied: mistune==3.0.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 63)) (3.0.2)
# Requirement already satisfied: nbclient==0.10.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 64)) (0.10.0)
# Requirement already satisfied: nbconvert==7.16.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 65)) (7.16.4)
# Requirement already satisfied: nbformat==5.10.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 66)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 67)) (1.6.0)
# Requirement already satisfied: notebook==7.2.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 68)) (7.2.1)
# Requirement already satisfied: notebook_shim==0.2.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 69)) (0.2.4)
# Requirement already satisfied: numpy==1.26.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 70)) (1.26.4)
# Requirement already satisfied: orjson==3.10.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 71)) (3.10.4)
# Requirement already satisfied: overrides==7.7.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 72)) (7.7.0)
# Requirement already satisfied: packaging==24.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 73)) (24.1)
# Requirement already satisfied: pandas==2.2.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 74)) (2.2.2)
# Requirement already satisfied: pandocfilters==1.5.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 75)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 76)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 77)) (4.9.0)
# Requirement already satisfied: platformdirs==4.2.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 78)) (4.2.2)
# Requirement already satisfied: prometheus_client==0.20.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 79)) (0.20.0)
# Requirement already satisfied: prompt_toolkit==3.0.47 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 80)) (3.0.47)
# Requirement already satisfied: psutil==5.9.8 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 81)) (5.9.8)
# Requirement already satisfied: ptyprocess==0.7.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 82)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 83)) (0.2.2)
# Requirement already satisfied: pycparser==2.22 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 84)) (2.22)
# Requirement already satisfied: pydantic==2.7.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 85)) (2.7.3)
# Requirement already satisfied: pydantic_core==2.18.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 86)) (2.18.4)
# Requirement already satisfied: Pygments==2.18.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 87)) (2.18.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 88)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv==1.0.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 89)) (1.0.1)
# Requirement already satisfied: python-json-logger==2.0.7 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 90)) (2.0.7)
# Requirement already satisfied: python-multipart==0.0.9 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 91)) (0.0.9)
# Requirement already satisfied: pytz==2024.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 92)) (2024.1)
# Requirement already satisfied: PyYAML==6.0.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 93)) (6.0.1)
# Requirement already satisfied: pyzmq==26.0.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 94)) (26.0.3)
# Requirement already satisfied: qtconsole==5.5.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 95)) (5.5.2)
# Requirement already satisfied: QtPy==2.4.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 96)) (2.4.1)
# Requirement already satisfied: referencing==0.35.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 97)) (0.35.1)
# Requirement already satisfied: requests==2.32.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 98)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 99)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 100)) (0.1.1)
# Requirement already satisfied: rich==13.7.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 101)) (13.7.1)
# Requirement already satisfied: rpds-py==0.18.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 102)) (0.18.1)
# Requirement already satisfied: scikit-learn==1.5.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 103)) (1.5.0)
# Requirement already satisfied: scipy==1.13.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 104)) (1.13.1)
# Requirement already satisfied: Send2Trash==1.8.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 105)) (1.8.3)
# Requirement already satisfied: shellingham==1.5.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 106)) (1.5.4)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 107)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 108)) (1.3.1)
# Requirement already satisfied: soupsieve==2.5 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 109)) (2.5)
# Requirement already satisfied: stack-data==0.6.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 110)) (0.6.3)
# Requirement already satisfied: starlette==0.37.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 111)) (0.37.2)
# Requirement already satisfied: terminado==0.18.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 112)) (0.18.1)
# Requirement already satisfied: threadpoolctl==3.5.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 113)) (3.5.0)
# Requirement already satisfied: tinycss2==1.3.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 114)) (1.3.0)
# Requirement already satisfied: tomli==2.0.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 115)) (2.0.1)
# Requirement already satisfied: tornado==6.4.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 116)) (6.4.1)
# Requirement already satisfied: traitlets==5.14.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 117)) (5.14.3)
# Requirement already satisfied: typer==0.12.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 118)) (0.12.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20240316 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 119)) (2.9.0.20240316)
# Requirement already satisfied: typing_extensions==4.12.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 120)) (4.12.2)
# Requirement already satisfied: tzdata==2024.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 121)) (2024.1)
# Requirement already satisfied: ujson==5.10.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 122)) (5.10.0)
# Requirement already satisfied: uri-template==1.3.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 123)) (1.3.0)
# Requirement already satisfied: urllib3==2.2.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 124)) (2.2.1)
# Requirement already satisfied: uvicorn==0.30.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 125)) (0.30.1)
# Requirement already satisfied: uvloop==0.19.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 126)) (0.19.0)
# Requirement already satisfied: watchfiles==0.22.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 127)) (0.22.0)
# Requirement already satisfied: wcwidth==0.2.13 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 128)) (0.2.13)
# Requirement already satisfied: webcolors==24.6.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 129)) (24.6.0)
# Requirement already satisfied: webencodings==0.5.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 130)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 131)) (1.8.0)
# Requirement already satisfied: websockets==12.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 132)) (12.0)
# Requirement already satisfied: Werkzeug==3.0.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 133)) (3.0.3)
# Requirement already satisfied: widgetsnbextension==4.0.11 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 134)) (4.0.11)
# Requirement already satisfied: setuptools>=40.1.0 in ./venv/lib/python3.10/site-packages (from jupyterlab==4.2.2->-r requirements.txt (line 55)) (59.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, precision_recall_curve
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# Load the original data
data = pd.read_csv('data/heart.csv')

# Separate features and target variable
X = data.drop('output', axis=1)
y_test = data['output']

# Load preprocessed data
X_preprocessed = joblib.load('models/X_preprocessed.pkl')

# Load trained model
best_model = joblib.load('models/best_model.pkl')

# Predictions on test data
y_pred = best_model.predict(X_preprocessed)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
plt.plot(fpr, tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.show()

# Precision-recall curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.show()
# Out:
# Accuracy: 0.9702970297029703
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97       138
#            1       0.97      0.98      0.97       165
#
#     accuracy                           0.97       303
#    macro avg       0.97      0.97      0.97       303
# weighted avg       0.97      0.97      0.97       303
